# %%
#Yolov4 convert ke tensorflow

# %%
# !python save_model.py --weights ./data/custom-yolov4-detector_best.weights --output ./checkpoints/yolov4-416 --input_size 416 --model yolov4
# Out:
# 2022-06-13 14:38:34.259365: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 416, 416, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 416, 416, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  tf.math.softplus (TFOpLambda)  (None, 416, 416, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  tf.math.tanh (TFOpLambda)      (None, 416, 416, 32  0           ['tf.math.softplus[0][0]']
#                                 )
#
# ...

# %%
#Test image
# !python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --images ./data/test1.jpg --count --output ./data/test_yolo.jpg
# Out:
# Number of total objects: 20
# (281.0, 601.0) (408.0, 796.0) (255, 0, 0) 2
# (249.0, 365.0) (346.0, 576.0) (255, 0, 0) 2
# (766.0, 345.0) (844.0, 592.0) (255, 0, 0) 2
# (585.0, 357.0) (685.0, 605.0) (255, 0, 0) 2
# (534.0, 297.0) (621.0, 409.0) (255, 0, 0) 2
# (427.0, 608.0) (553.0, 797.0) (255, 0, 0) 2
# (493.0, 371.0) (569.0, 568.0) (255, 0, 0) 2
# (28.0, 370.0) (115.0, 535.0) (255, 0, 0) 2
# (111.0, 606.0) (237.0, 762.0) (255, 0, 0) 2
# (965.0, 326.0) (1041.0, 497.0) (255, 0, 0) 2
# (231.0, 240.0) (310.0, 323.0) (255, 0, 0) 2
# (623.0, 320.0) (685.0, 405.0) (255, 0, 0) 2
# (120.0, 713.0) (280.0, 800.0) (255, 0, 0) 2
# (849.0, 468.0) (935.0, 629.0) (255, 0, 0) 2
# (1009.0, 391.0) (1099.0, 619.0) (255, 0, 0) 2
# (960.0, 461.0) (1032.0, 626.0) (255, 0, 0) 2
# (151.0, 183.0) (232.0, 284.0) (255, 0, 0) 2
# (820.0, 334.0) (879.0, 443.0) (255, 0, 0) 2
# (188.0, 220.0) (254.0, 311.0) (255, 0, 0) 2
# (825.0, 677.0) (911.0, 800.0) (255, 0, 0) 2

# %%
#test video
# !python detect_video.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --video ./data/test6.mp4 --count --output ./data/test-yolo.mp4 --score 0.4
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# Number of total objects: 6
# (650.0, 53.0) (721.0, 320.0) (255, 0, 0) 1
# (517.0, 0.0) (603.0, 201.0) (255, 0, 0) 1
# (635.0, 9.0) (679.0, 148.0) (255, 0, 0) 1
# (508.0, 163.0) (610.0, 478.0) (255, 0, 0) 1
# (426.0, 122.0) (500.0, 254.0) (255, 0, 0) 1
# (592.0, 118.0) (638.0, 382.0) (255, 0, 0) 1
# FPS: 0.28
# Number of total objects: 6
# (650.0, 55.0) (721.0, 319.0) (255, 0, 0) 1
# (516.0, 0.0) (603.0, 200.0) (255, 0, 0) 1
# (510.0, 169.0) (613.0, 473.0) (255, 0, 0) 1
# (636.0, 9.0) (678.0, 148.0) (255, 0, 0) 1
# (591.0, 118.0) (639.0, 382.0) (255, 0, 0) 1
# (426.0, 123.0) (499.0, 252.0) (255, 0, 0) 1
# FPS: 0.74
# Number of total objects: 5
# (650.0, 55.0) (721.0, 317.0) (255, 0, 0) 1
# (517.0, 0.0) (604.0, 199.0) (255, 0, 0) 1
# (636.0, 9.0) (678.0, 148.0) (255, 0, 0) 1
# (513.0, 153.0) (609.0, 489.0) (255, 0, 0) 1
# (590.0, 120.0) (638.0, 381.0) (255, 0, 0) 1
# ...

# %%
#test webcam
# !python detect_video.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --video 0 --count
# Out:
# Number of total objects: 1
# (77.0, 46.0) (481.0, 480.0) (255, 0, 0) 1
# FPS: 0.26
# Number of total objects: 1
# (99.0, 22.0) (466.0, 476.0) (255, 0, 0) 1
# FPS: 0.68
# Number of total objects: 1
# (108.0, 14.0) (460.0, 480.0) (255, 0, 0) 1
# FPS: 0.73
# Number of total objects: 1
# (93.0, 28.0) (463.0, 480.0) (255, 0, 0) 1
# FPS: 0.73
# Number of total objects: 1
# (50.0, 23.0) (506.0, 480.0) (255, 0, 0) 1
# FPS: 0.64
# Number of total objects: 1
# (43.0, 28.0) (522.0, 480.0) (255, 0, 0) 1
# FPS: 0.72
# Number of total objects: 1
# (112.0, 26.0) (522.0, 480.0) (255, 0, 0) 1
# FPS: 0.74
# Number of total objects: 1
# (138.0, 18.0) (493.0, 480.0) (255, 0, 0) 1
# FPS: 0.74
# Number of total objects: 1
# (130.0, 58.0) (438.0, 480.0) (255, 0, 0) 1
# FPS: 0.71
# Number of total objects: 1
# (134.0, 28.0) (504.0, 480.0) (255, 0, 0) 1
# FPS: 0.74
# Number of total objects: 1
# (156.0, 35.0) (485.0, 480.0) (255, 0, 0) 1
# FPS: 0.74
# Number of total objects: 1
# ...

# %%
# convert tiny yolo
# !python save_model.py --weights ./data/custom-yolov4-tiny-detector_best.weights --output ./checkpoints/yolov4-tiny-416 --input_size 416 --model yolov4 --tiny
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 416, 416, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 417, 417, 3)  0          ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 208, 208, 32  864         ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 208, 208, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  tf.nn.leaky_relu (TFOpLambda)  (None, 208, 208, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 209, 209, 32  0          ['tf.nn.leaky_relu[0][0]']
#  D)                             )
#
# ...

# %%
#test image
# !python detect.py --weights ./checkpoints/yolov4-tiny-416 --size 416 --model yolov4 --images ./data/test1.jpg --count --score 0.3 --output ./data/test-tiny.jpg
# Out:
# Number of total objects: 9
# (297.0, 599.0) (397.0, 794.0) (255, 0, 0) 2
# (26.0, 388.0) (121.0, 512.0) (255, 0, 0) 2
# (438.0, 611.0) (531.0, 789.0) (255, 0, 0) 2
# (250.0, 373.0) (330.0, 563.0) (255, 0, 0) 2
# (759.0, 339.0) (851.0, 592.0) (255, 0, 0) 2
# (114.0, 609.0) (242.0, 773.0) (255, 0, 0) 2
# (962.0, 316.0) (1035.0, 501.0) (255, 0, 0) 2
# (229.0, 235.0) (307.0, 331.0) (255, 0, 0) 2
# (835.0, 658.0) (898.0, 788.0) (255, 0, 0) 2

# %%
#test video
# !python detect_video.py --weights ./checkpoints/yolov4-tiny-416 --size 416 --model yolov4 --video ./data/test6.mp4 --count --output ./data/test-tiny.mp4 --score 0.4

# %%
# !python detect_video.py --weights ./checkpoints/yolov4-tiny-416 --size 416 --model yolov4 --video 0 --count --score 0.3
# Out:
# Number of total objects: 1
# (45.0, 95.0) (496.0, 453.0) (255, 0, 0) 1
# FPS: 1.26
# Number of total objects: 1
# (130.0, 7.0) (510.0, 480.0) (255, 0, 0) 1
# FPS: 5.26
# Number of total objects: 0
# FPS: 5.59
# Number of total objects: 1
# (50.0, 34.0) (501.0, 480.0) (255, 0, 0) 1
# FPS: 6.54
# Number of total objects: 2
# (3.0, 33.0) (548.0, 480.0) (255, 0, 0) 1
# (133.0, 5.0) (424.0, 402.0) (255, 0, 0) 1
# FPS: 7.14
# Number of total objects: 1
# (47.0, 0.0) (496.0, 480.0) (255, 0, 0) 1
# FPS: 6.49
# Number of total objects: 1
# (168.0, 91.0) (470.0, 472.0) (255, 0, 0) 1
# FPS: 7.35
# Number of total objects: 0
# FPS: 7.52
# Number of total objects: 1
# (28.0, 94.0) (531.0, 455.0) (255, 0, 0) 1
# FPS: 7.30
# Number of total objects: 1
# (149.0, 87.0) (490.0, 464.0) (255, 0, 0) 1
# FPS: 7.52
# Number of total objects: 1
# (134.0, 100.0) (516.0, 452.0) (255, 0, 0) 1
# FPS: 7.58
# Number of total objects: 1
# (125.0, 87.0) (518.0, 461.0) (255, 0, 0) 1
# FPS: 7.52
# ...

# %%
#safenotsafe
