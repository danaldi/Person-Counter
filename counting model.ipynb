# %%
#Test image
# !python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --images ./data/test1.jpg --count --output ./data/test_yolo.jpg  --score 0.1
# Out:
# (530.0, 0.0) (598.0, 90.0) (255, 0, 0) 1
# (659.0, 46.0) (728.0, 203.0) (255, 0, 0) 1
# (579.0, 109.0) (639.0, 252.0) (255, 0, 0) 1
# (628.0, 16.0) (684.0, 108.0) (255, 0, 0) 1
# (310.0, 0.0) (414.0, 54.0) (255, 0, 0) 1
# FPS: 0.72
# Number of total objects: 6
# (531.0, 0.0) (597.0, 90.0) (255, 0, 0) 1
# (658.0, 46.0) (727.0, 205.0) (255, 0, 0) 1
# (512.0, 178.0) (601.0, 336.0) (255, 0, 0) 1
# (579.0, 111.0) (639.0, 251.0) (255, 0, 0) 1
# (628.0, 15.0) (684.0, 108.0) (255, 0, 0) 1
# (310.0, 0.0) (414.0, 54.0) (255, 0, 0) 1
# FPS: 0.71
# Number of total objects: 6
# (657.0, 45.0) (727.0, 203.0) (255, 0, 0) 1
# (531.0, 0.0) (597.0, 90.0) (255, 0, 0) 1
# (512.0, 178.0) (601.0, 336.0) (255, 0, 0) 1
# (581.0, 102.0) (642.0, 243.0) (255, 0, 0) 1
# (628.0, 15.0) (681.0, 108.0) (255, 0, 0) 1
# (311.0, 0.0) (413.0, 54.0) (255, 0, 0) 1
# FPS: 0.69
# Number of total objects: 6
# (658.0, 46.0) (726.0, 201.0) (255, 0, 0) 1
# (531.0, 0.0) (597.0, 89.0) (255, 0, 0) 1
# ...

# %%
#test video
# !python detect_video.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --video ./data/test6.mp4 --count --output ./data/test-yolo.mp4 --score 0.1
# Out:
# Number of total objects: 6
# (583.0, 112.0) (643.0, 255.0) (255, 0, 0) 1
# (533.0, 0.0) (601.0, 91.0) (255, 0, 0) 1
# (645.0, 55.0) (719.0, 200.0) (255, 0, 0) 1
# (634.0, 21.0) (684.0, 117.0) (255, 0, 0) 1
# (522.0, 169.0) (601.0, 372.0) (255, 0, 0) 1
# (313.0, 0.0) (409.0, 54.0) (255, 0, 0) 1
# FPS: 0.35
# Number of total objects: 6
# (582.0, 114.0) (644.0, 253.0) (255, 0, 0) 1
# (645.0, 55.0) (719.0, 199.0) (255, 0, 0) 1
# (533.0, 0.0) (600.0, 92.0) (255, 0, 0) 1
# (634.0, 21.0) (685.0, 117.0) (255, 0, 0) 1
# (524.0, 177.0) (602.0, 370.0) (255, 0, 0) 1
# (313.0, 0.0) (409.0, 54.0) (255, 0, 0) 1
# FPS: 0.87
# Number of total objects: 6
# (581.0, 113.0) (643.0, 253.0) (255, 0, 0) 1
# (646.0, 55.0) (719.0, 199.0) (255, 0, 0) 1
# (533.0, 2.0) (601.0, 90.0) (255, 0, 0) 1
# (634.0, 20.0) (685.0, 117.0) (255, 0, 0) 1
# (530.0, 179.0) (601.0, 371.0) (255, 0, 0) 1
# (313.0, 0.0) (409.0, 54.0) (255, 0, 0) 1
# FPS: 0.96
# Number of total objects: 5
# ...

# %%
#test webcam
# !python detect_video.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --video 0 --count --score 0.
# Out:
# Number of total objects: 1
# (108.0, 12.0) (422.0, 463.0) (255, 0, 0) 1
# FPS: 0.24
# Number of total objects: 1
# (94.0, 18.0) (437.0, 457.0) (255, 0, 0) 1
# FPS: 0.80
# Number of total objects: 1
# (118.0, 3.0) (422.0, 469.0) (255, 0, 0) 1
# FPS: 0.85
# Number of total objects: 1
# (119.0, 25.0) (418.0, 448.0) (255, 0, 0) 1
# FPS: 0.80
# Number of total objects: 1
# (87.0, 17.0) (372.0, 460.0) (255, 0, 0) 1
# FPS: 0.81
# Number of total objects: 1
# (0.0, 23.0) (244.0, 455.0) (255, 0, 0) 1
# FPS: 0.81
# Number of total objects: 1
# (0.0, 26.0) (240.0, 449.0) (255, 0, 0) 1
# FPS: 0.80
# Number of total objects: 1
# (4.0, 11.0) (237.0, 460.0) (255, 0, 0) 1
# FPS: 0.81
# Number of total objects: 1
# (2.0, 21.0) (231.0, 451.0) (255, 0, 0) 1
# FPS: 0.79
# Number of total objects: 1
# (1.0, 38.0) (231.0, 438.0) (255, 0, 0) 1
# FPS: 0.79
# Number of total objects: 1
# (0.0, 23.0) (233.0, 450.0) (255, 0, 0) 1
# FPS: 0.79
# Number of total objects: 1
# ...

# %%
#test image
# !python detect.py --weights ./checkpoints/yolov4-tiny-416 --size 416 --model yolov4 --images ./data/test1.jpg --count --score 0.1 --output ./data/test-tiny.jpg
# Out:
# Number of total objects: 20
# (766.0, 346.0) (848.0, 486.0) (255, 0, 0) 2
# (427.0, 626.0) (527.0, 755.0) (255, 0, 0) 2
# (306.0, 628.0) (408.0, 751.0) (255, 0, 0) 2
# (485.0, 357.0) (575.0, 464.0) (255, 0, 0) 2
# (843.0, 493.0) (936.0, 585.0) (255, 0, 0) 2
# (967.0, 315.0) (1041.0, 451.0) (255, 0, 0) 2
# (250.0, 375.0) (334.0, 475.0) (255, 0, 0) 2
# (633.0, 322.0) (680.0, 389.0) (255, 0, 0) 2
# (547.0, 314.0) (604.0, 384.0) (255, 0, 0) 2
# (113.0, 594.0) (236.0, 740.0) (255, 0, 0) 2
# (832.0, 665.0) (948.0, 791.0) (255, 0, 0) 2
# (234.0, 236.0) (292.0, 310.0) (255, 0, 0) 2
# (589.0, 393.0) (679.0, 478.0) (255, 0, 0) 2
# (520.0, 282.0) (578.0, 355.0) (255, 0, 0) 2
# (1048.0, 398.0) (1107.0, 546.0) (255, 0, 0) 2
# (144.0, 247.0) (217.0, 314.0) (255, 0, 0) 2
# (970.0, 498.0) (1042.0, 592.0) (255, 0, 0) 2
# (720.0, 323.0) (768.0, 400.0) (255, 0, 0) 2
# (697.0, 346.0) (756.0, 425.0) (255, 0, 0) 2
# (25.0, 391.0) (121.0, 477.0) (255, 0, 0) 2

# %%
#test video
# !python detect_video.py --weights ./checkpoints/yolov4-tiny-416 --size 416 --model yolov4 --video ./data/test6.mp4 --count --output ./data/test-tiny.mp4 --score 0.1
# Out:
# Number of total objects: 5
# (586.0, 124.0) (646.0, 244.0) (255, 0, 0) 1
# (528.0, 198.0) (606.0, 349.0) (255, 0, 0) 1
# (649.0, 52.0) (712.0, 197.0) (255, 0, 0) 1
# (539.0, 0.0) (598.0, 84.0) (255, 0, 0) 1
# (627.0, 16.0) (683.0, 137.0) (255, 0, 0) 1
# FPS: 2.29
# Number of total objects: 5
# (585.0, 124.0) (646.0, 244.0) (255, 0, 0) 1
# (532.0, 199.0) (603.0, 350.0) (255, 0, 0) 1
# (649.0, 53.0) (712.0, 196.0) (255, 0, 0) 1
# (540.0, 0.0) (598.0, 83.0) (255, 0, 0) 1
# (627.0, 17.0) (682.0, 137.0) (255, 0, 0) 1
# FPS: 8.07
# Number of total objects: 5
# (586.0, 124.0) (646.0, 245.0) (255, 0, 0) 1
# (536.0, 202.0) (606.0, 350.0) (255, 0, 0) 1
# (650.0, 53.0) (712.0, 194.0) (255, 0, 0) 1
# (539.0, 0.0) (597.0, 84.0) (255, 0, 0) 1
# (628.0, 17.0) (683.0, 137.0) (255, 0, 0) 1
# FPS: 7.52
# Number of total objects: 5
# (584.0, 123.0) (644.0, 246.0) (255, 0, 0) 1
# (649.0, 54.0) (712.0, 192.0) (255, 0, 0) 1
# (538.0, 0.0) (597.0, 83.0) (255, 0, 0) 1
# ...

# %%
# !python detect_video.py --weights ./checkpoints/yolov4-tiny-416 --size 416 --model yolov4 --video 0 --count --score 0.1
# Out:
# Number of total objects: 1
# (137.0, 76.0) (523.0, 480.0) (255, 0, 0) 1
# FPS: 1.30
# Number of total objects: 0
# FPS: 6.29
# Number of total objects: 0
# FPS: 7.09
# Number of total objects: 0
# FPS: 7.52
# Number of total objects: 0
# FPS: 7.87
# Number of total objects: 0
# FPS: 8.06
# Number of total objects: 0
# FPS: 8.33
# Number of total objects: 0
# FPS: 8.33
# Number of total objects: 0
# FPS: 8.00
# Number of total objects: 1
# (213.0, 0.0) (545.0, 480.0) (255, 0, 0) 1
# FPS: 7.69
# Number of total objects: 0
# FPS: 7.75
# Number of total objects: 1
# (127.0, 66.0) (631.0, 480.0) (255, 0, 0) 1
# FPS: 8.07
# Number of total objects: 0
# FPS: 8.40
# Number of total objects: 0
# FPS: 8.55
# Number of total objects: 0
# FPS: 8.48
# Number of total objects: 0
# FPS: 4.93
# Number of total objects: 0
# FPS: 6.76
# Number of total objects: 1
# (155.0, 168.0) (413.0, 444.0) (255, 0, 0) 1
# FPS: 7.41
# Number of total objects: 0
# FPS: 7.94
# Number of total objects: 3
# ...
